# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
import pandas as pd

# %%
meta = pd.read_json('../data/meta.json',orient='split')

# %%
import pandas as pd

meta = pd.read_json('../data/meta.json',orient='split')
meta.TransplantDate = pd.to_datetime(meta.TransplantDate,unit='ms')

# %%
meta
# Out:
#                                     TransplantDate  Year  WeekTransplanted  \
# 2013-02-13_Felicity_ZJL_Z18_6_0.39      2013-02-13  2013                 7
# 2013-02-13_Shiren_ZJL_Z18_6_0.39        2013-02-13  2013                 7
# 2013-02-15_Amsterdam_ZJL_Z18_2_0.27     2013-02-15  2013                 7
# 2013-02-15_Felicity_ZJL_Z18_5_0.21      2013-02-15  2013                 7
# 2013-02-15_Olivia_ZJL_Z18_2_0.54        2013-02-15  2013                 7
# ...                                            ...   ...               ...
# 2024-07-18_Tymoty_VAP_V02_37_0.18       2024-07-18  2024                29
# 2024-07-24_Top 2417_VAP_V02_8_0.18      2024-07-24  2024                30
# 2024-07-29_King_SGB_S12_7_0.51          2024-07-29  2024                31
# 2024-07-29_King_SGB_S12_8_0.03          2024-07-29  2024                31
# 2024-07-29_Tymoty_SGB_S12_8_0.4         2024-07-29  2024                31
#
# ...
