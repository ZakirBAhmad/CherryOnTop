# %%
import os
import sys

sys.path.insert(0, os.path.abspath('..'))

# %%
import src.load as load
import src.table as table
import src.graphs_new as graphs
import src.graph_update as update
import src.graphs_calc as calc

# %% [markdown]
# session setup

# %%
session_state = {}

# %%
batch_preds = load.load_preds()

meta,y = load.load_actuals()
idx_dict = load.create_idx_dict(meta)
transplant_weeks = meta['transplant_week'].values
final_preds = table.shift_preds(batch_preds,transplant_weeks)
szn_act = table.shift_actuals(y,transplant_weeks)

session_state['current_data'] = {
    'meta': meta,
    'y': y,
    'idx_dict': idx_dict,
    'final_preds': final_preds,
    'szn_act': szn_act}

# %%
meta, y, t_weeks, idx_dict, total_kg = load.load_historical_data()
meta['yield'] = meta['total_kg'] / meta['ha']

session_state['historical_data'] = {
    'meta': meta,
    'y': y,
    't_weeks': t_weeks,
    'idx_dict': idx_dict,
    'total_kg': total_kg
}

# %%
mappings = load.load_mappings()
session_state['mappings'] = mappings

# %%
example_class = 'Cherry'

# %% [markdown]
# this season big sliding graph with the diff thingies (triple decker?)

# %%
stp_data = calc.sliding_transplant_projected(session_state['current_data']['final_preds'],example_class,session_state['current_data']['idx_dict'],session_state['current_data']['szn_act'])
stp_fig = graphs.sliding_transplant_projected(stp_data)
stp_fig.show()

# %%
week = 28
stp_fig = update.sliding_transplant_projected(stp_fig,stp_data,week)
stp_fig.show()

# %% [markdown]
# historical vs rn (all the diff yield graphs side by side with the other shit)

# %%
df, df_by_year, preds, actuals, df1, historical_yield = calc.year_yield(session_state['historical_data']['meta'], example_class, session_state['historical_data']['idx_dict'],session_state['current_data']['meta'], session_state['current_data']['idx_dict'],session_state['current_data']['final_preds'], session_state['current_data']['szn_act'])
yb_fig = graphs.yield_breakdown(df, df_by_year, preds, actuals,df1,historical_yield)
yb_fig.show()

# %%
week = 25

# %%
update.yield_breakdown(yb_fig,df,df_by_year,preds,actuals,df1,historical_yield,week)

# %%
kh_data = calc.kg_ha(session_state['historical_data']['meta'],example_class,session_state['historical_data']['idx_dict'])
kh_fig = graphs.kg_ha(kh_data)
kh_fig.show()

# %%
khp_data = calc.kg_ha_projected(session_state['current_data']['meta'],example_class,session_state['current_data']['idx_dict'],session_state['current_data']['final_preds'],session_state['current_data']['szn_act'])
khp_fig = graphs.kg_ha_projected(khp_data)
khp_fig.show()

# %%
update.kg_ha_projected(khp_fig,khp_data,30)

# %%
twy_df = calc.transplant_week_yield(session_state['historical_data']['meta'],example_class,session_state['historical_data']['idx_dict'])
twy_fig = graphs.transplant_week_yield(twy_df)
twy_fig.show()

# %%
twyp_df, twyp_preds, twyp_actuals = calc.transplant_week_yield_projected(session_state['current_data']['meta'],example_class,session_state['current_data']['idx_dict'],session_state['current_data']['final_preds'],session_state['current_data']['szn_act'])
twyp_fig = graphs.transplant_week_yield_projected(twyp_df, twyp_preds, twyp_actuals)
twyp_fig.show()

# %%
ry_df = calc.ranch_yield(session_state['historical_data']['meta'],example_class,session_state['historical_data']['idx_dict'],session_state['mappings'])
ry_fig = graphs.ranch_yield(ry_df,session_state['mappings'])
ry_fig.show()

# %%
ryp_df, ryp_preds, ryp_actuals = calc.ranch_yield_projected(session_state['current_data']['meta'],example_class,session_state['current_data']['idx_dict'],session_state['current_data']['final_preds'],session_state['current_data']['szn_act'],session_state['mappings'])
ryp_fig = graphs.ranch_yield_projected(ryp_df, ryp_preds, ryp_actuals,session_state['mappings'])
ryp_fig.show()

# %% [markdown]
# historical (sliding year/ha graphs)

# %%
year = 2020

# %%
st_data, st_kg_by_transplant_week, st_by_t_week = calc.sliding_transplant(year,example_class,session_state['historical_data']['meta'], session_state['historical_data']['y'], session_state['historical_data']['idx_dict'])
st_fig = graphs.sliding_transplant(st_data)
st_fig.show()
