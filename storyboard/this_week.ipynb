# %%
import os
import sys

sys.path.insert(0, os.path.abspath('..'))

# %%
import src.graphs as graph
import src.load as load
import src.table as table

# %%
import app.paths as paths

# %%
c_preds, r_preds = load.load_preds()

# %%
meta,y = load.load_actuals()
t_weeks = meta['transplant_week'].values
idx_dict = load.create_idx_dict(meta)

# %%
season_act = table.shift_actuals(y,t_weeks)

# %%
graphs = {str(week): graph.pred_evolution(week,season_act,szn_init_kg,szn_adj_kg,idx_dict) for week in range(52)}

# %%
graphs['20']

# %%
tables = {}
for i in range(51):
    this_week = i
    row = {}
    for c in idx_dict['class'].keys():
        preds_by_week, kg_so_far = table.week_class_table(this_week,c,szn_adj_kg,szn_act_kg,idx_dict)
        row[c] = preds_by_week, kg_so_far
    tables[i] = row

# %%
row = tables[0]

# %%
df = table.frame_table(preds_by_week, kg_so_far, idx_dict, this_week)
