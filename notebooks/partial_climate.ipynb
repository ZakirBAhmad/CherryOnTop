# %%
import sys
import os
# Add the parent directory to sys.path
sys.path.append(os.path.abspath('..'))

# %%
import pandas as pd
import numpy as np
import src.preprocessing as pre

from src.utils import train_harvest_model, predict_harvest, train_partial_climate

# %%
train, test, mappings, meta = pre.separate_year('../data/planting_meta.json','../data/y.csv','../data/mapping_dict.json')
# Out:
# 2025-05-26 13:41:55.335 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 13:41:55.376
# ...
#   command:
#
#     streamlit run /Users/zakir/anaconda3/envs/cherry/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-05-26 13:41:55.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 13:41:55.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 13:41:55.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 13:41:55.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
model = train_partial_climate(train,num_epochs=50,lr = 1e-4)
# Out:
# Epoch [1/50], Start Loss: 1024348.5496, End Loss: 1022982.2402, Avg Loss: [1024348.54955808 1024110.8270202  1023969.38320707 1023832.22885101
#  1023693.70265152 1023554.09816919 1023413.18118687 1023269.78188131
#  1023125.64835859 1022982.24021465], Min Loss: 9.0000
# Epoch [2/50], Start Loss: 835696.7091, End Loss: 833813.3411, Avg Loss: [835696.70912247 835501.23184975 835309.83570076 835111.95486111
#  834907.61316288 834697.5552399  834482.86332071 834263.21969697
#  834039.93592172 833813.34106692], Min Loss: 9.0000
# Epoch [3/50], Start Loss: 744411.5041, End Loss: 743491.8854, Avg Loss: [744411.50410354 744348.96306818 744272.765625   744185.81060606
#  744089.06549874 743983.43892045 743870.29419192 743749.93450126
#  743623.69113005 743491.88541667], Min Loss: 9.0000
# Epoch [4/50], Start Loss: 701972.0414, End Loss: 701137.4811, Avg Loss: [701972.04135101 701919.63636364 701839.36616162 701747.61363636
#  701643.99921086 701528.25189394 701412.85195707 701350.78314394
# ...
