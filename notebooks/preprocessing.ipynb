# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
import pandas as pd
import numpy as np

# %%
from scipy.stats import zscore

# %%
folder_path = '../data/'

# %%
import src.preprocess as pre

# %%
filtered_meta, filtered_y, df_normalized, filtered_schedule, scaler = pre.create_files(folder_path)
# Out:
# /Users/zakir/Documents/Projects/CherryOnTop/src/preprocess.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Type'] = df['Type'].str.rstrip()
# /Users/zakir/Documents/Projects/CherryOnTop/src/preprocess.py:152: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Parcel'] = df['Parcel'].str.upper()
# /Users/zakir/Documents/Projects/CherryOnTop/src/preprocess.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
filtered_meta.to_json('../data/processed/meta.json',orient='split')

# %%
pd.DataFrame(filtered_y).to_csv('../data/processed/y.csv')

# %%
filtered_schedule.to_csv('../data/processed/schedule.csv')

# %%
filtered_meta
# Out:
#      TransplantDate Parcel  Lot ProducerCode    Variety      Ha Class  \
# 0        2012-03-28    N02    7          OAP     Shiren  0.1330   CHE
# 11       2013-02-13    Z18    6          ZJL   Felicity  0.3938   CHE
# 12       2013-02-13    Z18    6          ZJL     Shiren  0.3938   CHE
# 13       2013-02-15    Z18    2          ZJL  Amsterdam  0.2700  BSUF
# 14       2013-02-15    Z18    2          ZJL     Olivia  0.5400  BSUF
# ...             ...    ...  ...          ...        ...     ...   ...
# 4209     2024-07-25    S12    4          SGB   Top 2323  0.1530   CHE
# 4210     2024-07-25    S12    4          SGB     Yoyomo  0.1020  BSUF
# 4211     2024-07-29    S12    7          SGB       King  0.5100  BSUF
# 4212     2024-07-29    S12    8          SGB       King  0.0306  BSUF
# 4213     2024-07-29    S12    8          SGB     Tymoty  0.3978   CHE
#
#               Type  WeekTransplanted   WeekCos   WeekSin  Year  \
# ...

# %%
import src.load as load

train_dataset, test_dataset, schedule,mapping_dict, reverse_mappings, test_meta = load.separate_prop('../data/processed/')

# %%
train_dataset.get_shapes()
# Out:
# {'features': torch.Size([3032, 5]),
#  'encoded_features': torch.Size([3032, 6]),
#  'climate_data': torch.Size([3032, 100, 9]),
#  'Y_kilos': torch.Size([2715, 41])}
